# %%
#modules we'll use
import numpy as np
import pandas as pd

# %%
#for box_cox transformation
from scipy import stats

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.0-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp 450 g8\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.0

# %%
#for minmax_scaling
from mlxtend.preprocessing import minmax_scaling

# %%
#plotting modules
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#set seed for reproducibility
np.random.seed(0)

# %%
original_data=np.random.exponential(size=1000)
#minmax_scale the data between 0 & 1
scaled_data=minmax_scaling(original_data,columns=[0])
#plot 2 together to compare
fig,ax=plt.subplots(1,2,figsize=(15,3))
sns.histplot(original_data,ax=ax[0],kde=True,legend=False)
ax[0].set_title("original Data")
sns.histplot(scaled_data,ax=ax[1],kde=True,legend=False)
ax[1].set_title("scaled Data")
plt.show()

# %%
# normalize the exponential data with boxcox
normalized_data = stats.boxcox(original_data)

# plot both together to compare
fig, ax=plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(normalized_data[0], ax=ax[1], kde=True, legend=False)
ax[1].set_title("Normalized data")
plt.show()

# %% [markdown]
# Normal distribution:
# Also known as the "bell curve", this is a specific statistical distribution where a roughly equal observations fall above and below the mean, the mean and the median are the same, and there are more observations closer to the mean. The normal distribution is also known as the Gaussian distribution.
